# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')
from itertools import product

# %%
res = pd.read_csv('scripts/bin_class_out/result.csv', index_col=0)
res
# Out:
#                   mutation               strategy  gems  n_cols  overall_best  \
# 1           point_mutation        MatchPMStrategy     0     100     -0.967337
# 2           point_mutation        MatchPMStrategy     0      50     -0.952261
# 3           point_mutation        MatchPMStrategy     0      10     -0.942211
# 4           point_mutation        MatchPMStrategy     5     100     -0.959799
# 5           point_mutation        MatchPMStrategy     5      50     -0.967337
# 6           point_mutation        MatchPMStrategy     5      10     -0.949749
# 7           point_mutation        MatchPMStrategy    10     100     -0.962312
# 8           point_mutation        MatchPMStrategy    10      50     -0.957286
# 9           point_mutation        MatchPMStrategy    10      10     -0.944724
# 10         single_mutation        MatchSMStrategy     0     100     -0.967337
# 11         single_mutation        MatchSMStrategy     0      50     -0.962312
# 12         single_mutation        MatchSMStrategy     0      10     -0.937186
# 13         single_mutation        MatchSMStrategy     5     100     -0.962312
# 14         single_mutation        MatchSMStrategy     5      50     -0.969849
# 15         single_mutation        MatchSMStrategy     5      10     -0.957286
# 16         single_mutation        MatchSMStrategy    10     100     -0.964824
# 17         single_mutation        MatchSMStrategy    10      50     -0.972362
# 18         single_mutation        MatchSMStrategy    10      10     -0.954774
# 19         single_mutation  MatchByActiveStrategy     0     100     -0.967337
# 20         single_mutation  MatchByActiveStrategy     0      50     -0.962312
# 21         single_mutation  MatchByActiveStrategy     0      10     -0.937186
# 22         single_mutation  MatchByActiveStrategy     5     100     -0.977387
# 23         single_mutation  MatchByActiveStrategy     5      50     -0.962312
# 24         single_mutation  MatchByActiveStrategy     5      10     -0.944724
# 25         single_mutation  MatchByActiveStrategy    10     100     -0.967337
# 26         single_mutation  MatchByActiveStrategy    10      50     -0.969849
# 27         single_mutation  MatchByActiveStrategy    10      10     -0.944724
# 28  probabilistic_mutation        MatchSMStrategy     0     100     -0.959799
# 29  probabilistic_mutation        MatchSMStrategy     0      50     -0.954774
# 30  probabilistic_mutation        MatchSMStrategy     0      10     -0.932161
# 31  probabilistic_mutation        MatchSMStrategy     5     100     -0.959799
# 32  probabilistic_mutation        MatchSMStrategy     5      50     -0.954774
# 33  probabilistic_mutation        MatchSMStrategy     5      10     -0.942211
# 34  probabilistic_mutation        MatchSMStrategy    10     100     -0.959799
# 35  probabilistic_mutation        MatchSMStrategy    10      50     -0.954774
# 36  probabilistic_mutation        MatchSMStrategy    10      10     -0.942211
# 37  probabilistic_mutation  MatchByActiveStrategy     0     100     -0.959799
# 38  probabilistic_mutation  MatchByActiveStrategy     0      50     -0.954774
# 39  probabilistic_mutation  MatchByActiveStrategy     0      10     -0.932161
# 40  probabilistic_mutation  MatchByActiveStrategy     5     100     -0.959799
# 41  probabilistic_mutation  MatchByActiveStrategy     5      50     -0.947236
# 42  probabilistic_mutation  MatchByActiveStrategy     5      10     -0.947236
# 43  probabilistic_mutation  MatchByActiveStrategy    10     100     -0.959799
# 44  probabilistic_mutation  MatchByActiveStrategy    10      50     -0.957286
# 45  probabilistic_mutation  MatchByActiveStrategy    10      10     -0.947236
#
#     overall_best_mean  overall_best_std  test_error_best  test_error_mean  \
# 1           -0.965327          0.001124        -0.959064        -0.903216
# 23        0.019941                370             18.50              5338
# 24        0.039769                499             24.95              3692
# 25        0.029738                444             22.20              7327
# 26        0.021990                438             21.90              6187
# 27        0.031594                509             25.45              3967
# 28        0.021399                  0              0.00                 0
# 29        0.027548                  0              0.00                 0
# 30        0.021762                  0              0.00                 0
# 31        0.021399                  0              0.00                 0
# 32        0.027548                  0              0.00                 0
# 33        0.026958                 10              0.50                12
# 34        0.021399                  0              0.00                 0
# 35        0.027548                  0              0.00                 0
# 36        0.026958                 11              0.55                14
# 37        0.021399                  0              0.00                 0
# 38        0.027548                  0              0.00                 0
# 39        0.021762                  0              0.00                 0
# 40        0.019823                150              7.50              4216
# 41        0.019667                156              7.80              4061
# 42        0.028546                172              8.60              2806
# 43        0.019649                183              9.15              5072
# 44        0.022970                142              7.10              4335
# 45        0.028546                172              8.60              2806
#
#     worse_gems_mean
# 1              0.00
# 2              0.00
# 3              0.00
# 4             10.40
# 5              7.80
# 6             10.80
# 7             15.65
# 8             16.00
# 9             11.95
# 10             0.00
# 11             0.00
# 12             0.00
# 13             3.95
# 14             5.95
# 15             9.55
# 16             7.40
# 17            10.45
# 18            11.15
# 19             0.00
# 20             0.00
# 21             0.00
# 22           328.40
# 23           266.90
# 24           184.60
# 25           366.35
# 26           309.35
# 27           198.35
# 28             0.00
# 29             0.00
# 30             0.00
# 31             0.00
# 32             0.00
# 33             0.60
# 34             0.00
# 35             0.00
# 36             0.70
# 37             0.00
# 38             0.00
# 39             0.00
# 40           210.80
# 41           203.05
# 42           140.30
# 43           253.60
# 44           216.75
# 45           140.30

# %% [markdown]
# When using probabilistic mutation, gems with large graphs (50 nodes and 100 nodes) are never applied, due to very low probability of match. Probabilistic mutation was able to converge to zero error without gems, however, with gems (in case where there were applications - graph with 10 nodes) the mean of best generation was signifiantly smaller, indicating more stable results.

# %%
from pycgp import single_mutation, point_mutation, probabilistic_mutation
from pycgp.gems import MatchByActiveStrategy, MatchPMStrategy, MatchSMStrategy

mutations = [(single_mutation, MatchSMStrategy),
 (point_mutation, MatchPMStrategy),
 (probabilistic_mutation, MatchSMStrategy),
 (probabilistic_mutation, MatchByActiveStrategy)]
gems = [0, 5, 10]
n_cols = [10, 50, 100]

# %%
def plot_fitness(mutations, gems, n_cols):
    _, ax = plt.subplots(1,3, figsize=(10,4))
    for n_col, axis in zip(n_cols, ax):
        files = [f'scripts/bin_class_out//{m.__name__}-{s.__name__}-gems{g}-n_cols{c}.csv' for (m, s), g, c in product(mutations, gems, [n_col])]
        colors = sns.color_palette("Set2", len(files))
        for file, color in zip(files, colors):
            data = pd.DataFrame.from_csv(file)
            data['best_fitness'].plot(ax=axis, label=file, c=color)           
            axis.legend()
            axis.set_ylim(-1,0)
    return ax

# %%
mutations = [(single_mutation, MatchSMStrategy)]
gems=[0, 5, 10]
n_cols=[10, 50, 100]

ax = plot_fitness(mutations, gems, n_cols)

# %%
mutations = [(point_mutation, MatchPMStrategy)]
gems = [0, 5, 10]
n_cols = [10, 50, 100]

ax = plot_fitness(mutations, gems, n_cols)

# %%
mutations = [(probabilistic_mutation, MatchByActiveStrategy)]
gems = [0, 5, 10]
n_cols = [10, 50, 100]

ax = plot_fitness(mutations, gems, n_cols)
