# %% [markdown]
# # Gem usage analysis
#
# Numbers of good and bad gem applications.

# %%
import numpy as np
import pandas as pd
from utils import DataIterator

# %%
symreg = DataIterator('scripts/symbolic_basic/')
bincls = DataIterator('scripts/bin_class_out/')
santaf = DataIterator('scripts/santa_fe_out/')

# %%
def gem_usage_info(di):
    data = []
    for m, s, g, c, raw in di.iterate_folder():
        count  = np.mean([len(x['gem_data']) for x in raw])
        better = np.mean([x['gem_better_after'] for x in raw])
        worse  = np.mean([x['gem_worse_after']  for x in raw])
        data.append([m,s,g,count,better,worse])
    data = pd.DataFrame(data)
    data.columns = ['m', 's', 'g', 'count', 'better', 'worse']
    return data[data.g != 0].groupby(['m', 's', 'g']).mean()

# %% [markdown]
# ## Symbolic regression

# %%
gem_usage_info(symreg)
# Out:
#                                                      count      better  \
# m                      s                     g
# point_mutation         MatchPMStrategy       5    6.433333  109.783333
#                                              10   9.616667  140.500000
# probabilistic_mutation MatchByActiveStrategy 5    8.016667   32.100000
#                                              10   9.016667   33.700000
#                        MatchSMStrategy       5    4.966667    0.400000
#                                              10   8.600000    1.250000
# single_mutation        MatchByActiveStrategy 5   10.250000   50.716667
#                                              10  13.333333   63.100000
#                        MatchSMStrategy       5    5.333333   28.200000
#                                              10   9.216667   41.700000
#
#                                                      worse
# m                      s                     g
# point_mutation         MatchPMStrategy       5   24.966667
#                                              10  33.366667
# probabilistic_mutation MatchByActiveStrategy 5   28.500000
#                                              10  31.016667
#                        MatchSMStrategy       5    0.383333
#                                              10   0.933333
# single_mutation        MatchByActiveStrategy 5   16.566667
#                                              10  24.183333
#                        MatchSMStrategy       5    8.366667
#                                              10  15.500000

# %% [markdown]
# ## Binary classification

# %%
gem_usage_info(bincls)
# Out:
#                                                      count     better  \
# m                      s                     g
# point_mutation         MatchPMStrategy       5    5.416667  71.233333
#                                              10   8.050000  81.966667
# probabilistic_mutation MatchByActiveStrategy 5    7.150000   7.966667
#                                              10   7.833333   8.283333
#                        MatchSMStrategy       5    4.733333   0.166667
#                                              10   7.150000   0.183333
# single_mutation        MatchByActiveStrategy 5    9.600000  19.883333
#                                              10  10.916667  23.183333
#                        MatchSMStrategy       5    4.883333  11.966667
#                                              10   8.750000  18.850000
#
#                                                     worse
# m                      s                     g
# point_mutation         MatchPMStrategy       5   6.966667
#                                              10  9.950000
# probabilistic_mutation MatchByActiveStrategy 5   7.200000
#                                              10  8.166667
#                        MatchSMStrategy       5   0.016667
#                                              10  0.016667
# single_mutation        MatchByActiveStrategy 5   4.183333
#                                              10  7.600000
#                        MatchSMStrategy       5   1.666667
#                                              10  2.016667

# %% [markdown]
# ## Santa Fe

# %%
gem_usage_info(santaf)
# Out:
#                                                      count      better  \
# m                      s                     g
# point_mutation         MatchPMStrategy       5    5.783333   80.033333
#                                              10  11.316667  128.666667
# probabilistic_mutation MatchByActiveStrategy 5    6.583333    6.883333
#                                              10   9.633333    7.066667
#                        MatchSMStrategy       5    4.983333    0.283333
#                                              10   9.283333    0.283333
# single_mutation        MatchByActiveStrategy 5    8.266667   57.800000
#                                              10  13.983333   89.916667
#                        MatchSMStrategy       5    5.516667   45.966667
#                                              10  10.683333   77.300000
#
#                                                      worse
# m                      s                     g
# point_mutation         MatchPMStrategy       5   10.033333
#                                              10  24.116667
# probabilistic_mutation MatchByActiveStrategy 5    6.600000
#                                              10   9.183333
#                        MatchSMStrategy       5    0.050000
#                                              10   0.083333
# single_mutation        MatchByActiveStrategy 5   12.916667
#                                              10  25.150000
#                        MatchSMStrategy       5    9.250000
#                                              10  15.066667
