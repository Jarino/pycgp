# %% [markdown]
# # Symbolic regression, results
#
# Target function: $ f(x) = \sin{x^2} + \sin{x + x^2} $
#
# CSVs created by `scripts/symbolic_regression.py` script.

# %% [markdown]
# # Symbolic regression

# %%
setts = np.array([x.split(',') for x in df['Unnamed: 0']])
setts[:,0]
# Out:
# array(['10', '50', '100', '10', '50', '100', '10', '50', '100', '10', '50',
#        '100', '10', '50', '100'],
#       dtype='<U3')

# %% [markdown]
# ## Point mutation

# %%
df = pd.read_csv('scripts/out/symreg_pm.csv')
setts = np.array([[int(y) for y in x.split(',')] for x in df['Unnamed: 0']])
df['nodes'] = setts[:, 0]
df['gems'] = setts[:, 1]
df['uses'] = setts[:, 2]
df[['nodes', 'gems', 'uses', 'best fitness', 'mean of best individual', 'std of best indvidiual', 'g_better avg', 'g_worse avg']][((df['uses'] == 0) & (df['gems'] == 0)) |((df['uses'] == 30) & (df['gems'] != 0))]
# Out:
#     nodes  gems  uses  best fitness  mean of best individual  \
# 0      10     0     0      0.148973                 0.359569
# 1      50     0     0      0.000000                 0.282891
# 2     100     0     0      0.167763                 0.307991
# 6      10     5    30      0.199623                 0.397679
# 7      50     5    30      0.053798                 0.295439
# 8     100     5    30      0.198590                 0.324479
# 12     10    10    30      0.164879                 0.398036
# 13     50    10    30      0.163178                 0.306941
# 14    100    10    30      0.113260                 0.347173
#
#     std of best indvidiual  g_better avg  g_worse avg
# 0                 0.087830          0.00         0.00
# 1                 0.116849          0.00         0.00
# 2                 0.077190          0.00         0.00
# 6                 0.099685        121.30        24.50
# 7                 0.116299         80.45        33.45
# ...

# %%
df['g_better'] + df['g_worse']
# Out:
# 0         0
# 1         0
# 2         0
# 3     24971
# 4     15830
# 5      5762
# 6      2916
# 7      2278
# 8      1798
# 9     18178
# 10     9835
# 11    17892
# 12     4199
# 13     3135
# 14     2654
# dtype: int64

# %% [markdown]
# ## Single mutation all

# %%
df = pd.read_csv('scripts/out/symreg_sm_all.csv')
setts = np.array([[int(y) for y in x.split(',')] for x in df['Unnamed: 0']])
df['nodes'] = setts[:, 0]
df['gems'] = setts[:, 1]
df['uses'] = setts[:, 2]
df[['nodes', 'gems', 'uses', 'best fitness', 'mean of best individual', 'std of best indvidiual', 'g_better avg', 'g_worse avg']][((df['uses'] == 0) & (df['gems'] == 0)) |((df['uses'] == 30) & (df['gems'] != 0))]
# Out:
#     nodes  gems  uses  best fitness  mean of best individual  \
# 0      10     0     0      0.090185                 0.372760
# 1      50     0     0      0.000000                 0.271078
# 2     100     0     0      0.121879                 0.314480
# 6      10     5    30      0.117614                 0.365970
# 7      50     5    30      0.057092                 0.311986
# 8     100     5    30      0.175893                 0.351501
# 12     10    10    30      0.000000                 0.340701
# 13     50    10    30      0.000000                 0.286671
# 14    100    10    30      0.054159                 0.310510
#
#     std of best indvidiual  g_better avg  g_worse avg
# 0                 0.122868          0.00         0.00
# 1                 0.128078          0.00         0.00
# 2                 0.102917          0.00         0.00
# 6                 0.108160         63.55        32.50
# 7                 0.128519         20.95         9.20
# ...

# %% [markdown]
# ## Single mutation active

# %%
df = pd.read_csv('scripts/out/symreg_sm_active.csv')
setts = np.array([[int(y) for y in x.split(',')] for x in df['Unnamed: 0']])
df['nodes'] = setts[:, 0]
df['gems'] = setts[:, 1]
df['uses'] = setts[:, 2]
df[['nodes', 'gems', 'uses', 'best fitness', 'mean of best individual', 'std of best indvidiual', 'g_better avg', 'g_worse avg']][((df['uses'] == 0) & (df['gems'] == 0)) |((df['uses'] == 30) & (df['gems'] != 0))]
# Out:
#     nodes  gems  uses  best fitness  mean of best individual  \
# 0      10     0     0      0.090185                 0.372760
# 1      50     0     0      0.000000                 0.271078
# 2     100     0     0      0.121879                 0.314480
# 6      10     5    30      0.208486                 0.364766
# 7      50     5    30      0.043247                 0.289751
# 8     100     5    30      0.193370                 0.374188
# 12     10    10    30      0.177179                 0.329473
# 13     50    10    30      0.164081                 0.297420
# 14    100    10    30      0.167493                 0.375127
#
#     std of best indvidiual  g_better avg  g_worse avg
# 0                 0.122868          0.00         0.00
# 1                 0.128078          0.00         0.00
# 2                 0.102917          0.00         0.00
# 6                 0.080324         45.60       156.35
# 7                 0.129461         46.65       220.40
# ...

# %% [markdown]
# ## Probabilistic mutation all

# %%
df = pd.read_csv('scripts/out/symreg_probm_all.csv')
setts = np.array([[int(y) for y in x.split(',')] for x in df['Unnamed: 0']])
df['nodes'] = setts[:, 0]
df['gems'] = setts[:, 1]
df['uses'] = setts[:, 2]
df[['nodes', 'gems', 'uses', 'best fitness', 'mean of best individual', 'std of best indvidiual', 'g_better avg', 'g_worse avg']][((df['uses'] == 0) & (df['gems'] == 0)) |((df['uses'] == 30) & (df['gems'] != 0))]
# Out:
#     nodes  gems  uses  best fitness  mean of best individual  \
# 0      10     0     0      0.117614                 0.219439
# 1      50     0     0      0.120955                 0.211337
# 2     100     0     0      0.167763                 0.254630
# 6      10     5    30      0.000000                 0.200630
# 7      50     5    30      0.120955                 0.211337
# 8     100     5    30      0.167763                 0.254630
# 12     10    10    30      0.117614                 0.208984
# 13     50    10    30      0.120955                 0.211337
# 14    100    10    30      0.167763                 0.254630
#
#     std of best indvidiual  g_better avg  g_worse avg
# 0                 0.079739          0.00         0.00
# 1                 0.059655          0.00         0.00
# 2                 0.080073          0.00         0.00
# 6                 0.114505          1.35         2.75
# 7                 0.059655          0.00         0.00
# ...

# %% [markdown]
# ## Probabilistic mutation active

# %%
df = pd.read_csv('scripts/out/symreg_probm_active.csv')
setts = np.array([[int(y) for y in x.split(',')] for x in df['Unnamed: 0']])
df['nodes'] = setts[:, 0]
df['gems'] = setts[:, 1]
df['uses'] = setts[:, 2]
df[['nodes', 'gems', 'uses', 'best fitness', 'mean of best individual', 'std of best indvidiual', 'g_better avg', 'g_worse avg']][((df['uses'] == 0) & (df['gems'] == 0)) |((df['uses'] == 30) & (df['gems'] != 0))]
# Out:
#     nodes  gems  uses  best fitness  mean of best individual  \
# 0      10     0     0      0.117614                 0.219439
# 1      50     0     0      0.120955                 0.211337
# 2     100     0     0      0.167763                 0.254630
# 6      10     5    30      0.000000                 0.195192
# 7      50     5    30      0.000000                 0.187302
# 8     100     5    30      0.000000                 0.218864
# 12     10    10    30      0.000000                 0.223514
# 13     50    10    30      0.000000                 0.196622
# 14    100    10    30      0.000000                 0.238097
#
#     std of best indvidiual  g_better avg  g_worse avg
# 0                 0.079739          0.00         0.00
# 1                 0.059655          0.00         0.00
# 2                 0.080073          0.00         0.00
# 6                 0.094030         39.15       170.25
# 7                 0.114837         21.25       122.75
# ...
