# %%
import pandas as pd

# %%
data = pd.read_csv('result.csv')

# %%
data
# Out:
#     Unnamed: 0                mutation               strategy  gems  n_cols  \
# 0            1          point_mutation        MatchPMStrategy     0      10
# 1            2          point_mutation        MatchPMStrategy     0      50
# 2            3          point_mutation        MatchPMStrategy     0     100
# 3            4          point_mutation        MatchPMStrategy     5      10
# 4            5          point_mutation        MatchPMStrategy     5      50
# 5            6          point_mutation        MatchPMStrategy     5     100
# 6            7          point_mutation        MatchPMStrategy    10      10
# 7            8          point_mutation        MatchPMStrategy    10      50
# 8            9          point_mutation        MatchPMStrategy    10     100
# 9           10         single_mutation        MatchSMStrategy     0      10
# 10          11         single_mutation        MatchSMStrategy     0      50
# ...
