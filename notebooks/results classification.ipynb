# %% [markdown]
# # Results

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Binary classification

# %%
setts = np.array([x.split(',') for x in df['Unnamed: 0']])
setts[:,0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7561701e5c12> in <module>()
# ----> 1 setts = np.array([x.split(',') for x in df['Unnamed: 0']])
#       2 setts[:,0]
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Point mutation

# %%
df = pd.read_csv('scripts/out/binclass_pm_test.csv')
setts = np.array([[int(y) for y in x.split(',')] for x in df['Unnamed: 0']])
df['nodes'] = setts[:, 0]
df['gems'] = setts[:, 1]
df['uses'] = setts[:, 2]
df[['nodes', 'gems', 'uses', 'best fitness', 'mean of best individual', 'std of best indvidiual', 'g_better avg', 'g_worse avg']][((df['uses'] == 0) & (df['gems'] == 0)) |((df['uses'] == 30) & (df['gems'] != 0))]
# Out:
#     nodes  gems  uses  best fitness  mean of best individual  \
# 0      10     0     0     -0.942211                -0.898995
# 1      50     0     0     -0.959799                -0.932663
# 2     100     0     0     -0.954774                -0.931156
# 6      10     5    30     -0.937186                -0.903015
# 7      50     5    30     -0.947236                -0.912060
# 8     100     5    30     -0.954774                -0.923116
# 12     10    10    30     -0.942211                -0.921608
# 13     50    10    30     -0.932161                -0.921106
# 14    100    10    30     -0.954774                -0.936683
#
#     std of best indvidiual  g_better avg  g_worse avg
# 0                 0.035190           0.0          0.0
# 1                 0.020063           0.0          0.0
# 2                 0.021177           0.0          0.0
# 6                 0.017738          82.4         10.2
# 7                 0.035248          36.0          9.6
# 8                 0.019758          64.4          6.2
# 12                0.018491          82.6          7.6
# 13                0.009211          75.4         18.8
# 14                0.010225          85.8         18.4

# %% [markdown]
# ## Single mutation all

# %%
df = pd.read_csv('scripts/out/binclass_sm_all_test.csv')
setts = np.array([[int(y) for y in x.split(',')] for x in df['Unnamed: 0']])
df['nodes'] = setts[:, 0]
df['gems'] = setts[:, 1]
df['uses'] = setts[:, 2]
df[['nodes', 'gems', 'uses', 'best fitness', 'mean of best individual', 'std of best indvidiual', 'g_better avg', 'g_worse avg']][((df['uses'] == 0) & (df['gems'] == 0)) |((df['uses'] == 30) & (df['gems'] != 0))]
# Out:
#     nodes  gems  uses  best fitness  mean of best individual  \
# 0      10     0     0     -0.919598                -0.898995
# 1      50     0     0     -0.942211                -0.922613
# 2     100     0     0     -0.952261                -0.939196
# 6      10     5    30     -0.919598                -0.889950
# 7      50     5    30     -0.967337                -0.920603
# 8     100     5    30     -0.954774                -0.931156
# 12     10    10    30     -0.919598                -0.902010
# 13     50    10    30     -0.967337                -0.939698
# 14    100    10    30     -0.947236                -0.936683
#
#     std of best indvidiual  g_better avg  g_worse avg
# 0                 0.027173           0.0          0.0
# 1                 0.023322           0.0          0.0
# 2                 0.007351           0.0          0.0
# 6                 0.046067           1.0          2.4
# 7                 0.032744           8.0          6.6
# 8                 0.025946           7.2         10.2
# 12                0.014651          32.8          7.0
# 13                0.015891          13.8         12.0
# 14                0.008468           8.8         14.8

# %% [markdown]
# ## Single mutation active

# %%
df = pd.read_csv('scripts/out/binclass_sm_active_test.csv')
setts = np.array([[int(y) for y in x.split(',')] for x in df['Unnamed: 0']])
df['nodes'] = setts[:, 0]
df['gems'] = setts[:, 1]
df['uses'] = setts[:, 2]
df[['nodes', 'gems', 'uses', 'best fitness', 'mean of best individual', 'std of best indvidiual', 'g_better avg', 'g_worse avg']][((df['uses'] == 0) & (df['gems'] == 0)) |((df['uses'] == 30) & (df['gems'] != 0))]
# Out:
#     nodes  gems  uses  best fitness  mean of best individual  \
# 0      10     0     0     -0.919598                -0.898995
# 1      50     0     0     -0.942211                -0.922613
# 2     100     0     0     -0.952261                -0.939196
# 6      10     5    30     -0.924623                -0.883417
# 7      50     5    30     -0.954774                -0.923116
# 8     100     5    30     -0.944724                -0.928643
# 12     10    10    30     -0.924623                -0.883417
# 13     50    10    30     -0.942211                -0.930151
# 14    100    10    30     -0.962312                -0.940704
#
#     std of best indvidiual  g_better avg  g_worse avg
# 0                 0.027173           0.0          0.0
# 1                 0.023322           0.0          0.0
# 2                 0.007351           0.0          0.0
# 6                 0.035412          25.6        187.6
# 7                 0.033090          13.8        204.0
# 8                 0.013725          14.8        316.8
# 12                0.035412          25.6        193.6
# 13                0.007687          15.8        257.8
# 14                0.023602          12.8        265.2

# %% [markdown]
# ## Probabilistic mutation all

# %%
df = pd.read_csv('scripts/out/binclass_probm_all_test.csv')
setts = np.array([[int(y) for y in x.split(',')] for x in df['Unnamed: 0']])
df['nodes'] = setts[:, 0]
df['gems'] = setts[:, 1]
df['uses'] = setts[:, 2]
df[['nodes', 'gems', 'uses', 'best fitness', 'mean of best individual', 'std of best indvidiual', 'g_better avg', 'g_worse avg']][((df['uses'] == 0) & (df['gems'] == 0)) |((df['uses'] == 30) & (df['gems'] != 0))]
# Out:
#     nodes  gems  uses  best fitness  mean of best individual  \
# 0      10     0     0     -0.934673                -0.918593
# 1      50     0     0     -0.954774                -0.927638
# 2     100     0     0     -0.952261                -0.935176
# 6      10     5    30     -0.934673                -0.918593
# 7      50     5    30     -0.954774                -0.927638
# 8     100     5    30     -0.952261                -0.935176
# 12     10    10    30     -0.934673                -0.918593
# 13     50    10    30     -0.954774                -0.927638
# 14    100    10    30     -0.952261                -0.935176
#
#     std of best indvidiual  g_better avg  g_worse avg
# 0                 0.011525           0.0          0.0
# 1                 0.020251           0.0          0.0
# 2                 0.020063           0.0          0.0
# 6                 0.011525           0.4          0.2
# 7                 0.020251           0.0          0.0
# 8                 0.020063           0.0          0.0
# 12                0.011525           0.4          0.2
# 13                0.020251           0.0          0.0
# 14                0.020063           0.0          0.0

# %% [markdown]
# ## Probabilistic mutation active

# %%
df = pd.read_csv('scripts/out/binclass_probm_active_test.csv')
setts = np.array([[int(y) for y in x.split(',')] for x in df['Unnamed: 0']])
df['nodes'] = setts[:, 0]
df['gems'] = setts[:, 1]
df['uses'] = setts[:, 2]
df[['nodes', 'gems', 'uses', 'best fitness', 'mean of best individual', 'std of best indvidiual', 'g_better avg', 'g_worse avg']][((df['uses'] == 0) & (df['gems'] == 0)) |((df['uses'] == 30) & (df['gems'] != 0))]
# Out:
#     nodes  gems  uses  best fitness  mean of best individual  \
# 0      10     0     0     -0.934673                -0.918593
# 1      50     0     0     -0.954774                -0.927638
# 2     100     0     0     -0.952261                -0.935176
# 6      10     5    30     -0.929648                -0.902513
# 7      50     5    30     -0.949749                -0.925628
# 8     100     5    30     -0.947236                -0.935176
# 12     10    10    30     -0.929648                -0.902513
# 13     50    10    30     -0.949749                -0.925628
# 14    100    10    30     -0.947236                -0.935678
#
#     std of best indvidiual  g_better avg  g_worse avg
# 0                 0.011525           0.0          0.0
# 1                 0.020251           0.0          0.0
# 2                 0.020063           0.0          0.0
# 6                 0.017071           8.8        123.6
# 7                 0.021058           4.8        214.4
# 8                 0.009718           8.0        235.6
# 12                0.017071           8.8        123.6
# 13                0.021058           4.8        253.6
# 14                0.009073           8.2        271.4
