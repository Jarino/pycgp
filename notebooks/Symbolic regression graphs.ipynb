# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')
from itertools import product

# %%
res = pd.read_csv('scripts/symbolic_out/sym_res.csv', index_col=0)
res = res.append(pd.read_csv('scripts/symbolic_out/sym_res_active.csv', index_col=0))
res
# Out:
#                   mutation               strategy  gems  n_cols  overall_best  \
# 1          single_mutation        MatchSMStrategy     0      10      0.159697
# 2          single_mutation        MatchSMStrategy     0      50      0.177179
# 3          single_mutation        MatchSMStrategy     0     100      0.000000
# 4          single_mutation        MatchSMStrategy     5      10      0.177179
# 5          single_mutation        MatchSMStrategy     5      50      0.000000
# 6          single_mutation        MatchSMStrategy     5     100      0.136095
# 7          single_mutation        MatchSMStrategy    10      10      0.198590
# 8          single_mutation        MatchSMStrategy    10      50      0.000000
# 9          single_mutation        MatchSMStrategy    10     100      0.124494
# 10          point_mutation        MatchPMStrategy     0      10      0.198590
# 11          point_mutation        MatchPMStrategy     0      50      0.000000
# 12          point_mutation        MatchPMStrategy     0     100      0.000000
# 13          point_mutation        MatchPMStrategy     5      10      0.159542
# 14          point_mutation        MatchPMStrategy     5      50      0.000000
# 15          point_mutation        MatchPMStrategy     5     100      0.043247
# 16          point_mutation        MatchPMStrategy    10      10      0.000000
# 17          point_mutation        MatchPMStrategy    10      50      0.000000
# 18          point_mutation        MatchPMStrategy    10     100      0.000000
# 19  probabilistic_mutation        MatchSMStrategy     0      10      0.000000
# 20  probabilistic_mutation        MatchSMStrategy     0      50      0.000000
# 21  probabilistic_mutation        MatchSMStrategy     0     100      0.043247
# 22  probabilistic_mutation        MatchSMStrategy     5      10      0.000000
# 23  probabilistic_mutation        MatchSMStrategy     5      50      0.000000
# 24  probabilistic_mutation        MatchSMStrategy     5     100      0.043247
# 25  probabilistic_mutation        MatchSMStrategy    10      10      0.000000
# 26  probabilistic_mutation        MatchSMStrategy    10      50      0.000000
# 27  probabilistic_mutation        MatchSMStrategy    10     100      0.043247
# 1          single_mutation  MatchByActiveStrategy     0      10      0.159697
# 2          single_mutation  MatchByActiveStrategy     0      50      0.177179
# 3          single_mutation  MatchByActiveStrategy     0     100      0.000000
# 4          single_mutation  MatchByActiveStrategy     5      10      0.000000
# 5          single_mutation  MatchByActiveStrategy     5      50      0.000000
# 6          single_mutation  MatchByActiveStrategy     5     100      0.000000
# 7          single_mutation  MatchByActiveStrategy    10      10      0.000000
# 8          single_mutation  MatchByActiveStrategy    10      50      0.000000
# 9          single_mutation  MatchByActiveStrategy    10     100      0.123367
# 10  probabilistic_mutation  MatchByActiveStrategy     0      10      0.000000
# 11  probabilistic_mutation  MatchByActiveStrategy     0      50      0.000000
# 12  probabilistic_mutation  MatchByActiveStrategy     0     100      0.043247
# 13  probabilistic_mutation  MatchByActiveStrategy     5      10      0.000000
# 14  probabilistic_mutation  MatchByActiveStrategy     5      50      0.000000
# 2                  0             0.00
# 3                  0             0.00
# 4                485            24.25
# 5                231            11.55
# 6                184             9.20
# 7                781            39.05
# 8                552            27.60
# 9                455            22.75
# 10                 0             0.00
# 11                 0             0.00
# 12                 0             0.00
# 13               646            32.30
# 14               943            47.15
# 15               656            32.80
# 16               804            40.20
# 17              1194            59.70
# 18               932            46.60
# 19                 0             0.00
# 20                 0             0.00
# 21                 0             0.00
# 22                53             2.65
# 23                 0             0.00
# 24                 0             0.00
# 25               145             7.25
# 26                 0             0.00
# 27                 0             0.00
# 1                  0             0.00
# 2                  0             0.00
# 3                  0             0.00
# 4               3703           185.15
# 5               5275           263.75
# 6               5929           296.45
# 7               3553           177.65
# 8               7112           355.60
# 9               7570           378.50
# 10                 0             0.00
# 11                 0             0.00
# 12                 0             0.00
# 13              3441           172.05
# 14              3212           160.60
# 15              2902           145.10
# 16              4083           204.15
# 17              3921           196.05
# 18              4897           244.85

# %% [markdown]
# When using probabilistic mutation, gems with large graphs (50 nodes and 100 nodes) are never applied, due to very low probability of match. Probabilistic mutation was able to converge to zero error without gems, however, with gems (in case where there were applications - graph with 10 nodes) the mean of best generation was signifiantly smaller, indicating more stable results.

# %%
from pycgp import single_mutation, point_mutation, probabilistic_mutation
from pycgp.gems import MatchByActiveStrategy, MatchPMStrategy, MatchSMStrategy

mutations = [(single_mutation, MatchSMStrategy),
 (point_mutation, MatchPMStrategy),
 (probabilistic_mutation, MatchSMStrategy),
 (probabilistic_mutation, MatchByActiveStrategy)]
gems = [0, 5, 10]
n_cols = [10, 50, 100]

# %%
def plot_fitness(mutations, gems, n_cols):
    files = [f'scripts/symbolic_out/{m.__name__}-{s.__name__}-gems{g}-n_cols{c}.csv' for (m, s), g, c in product(mutations, gems, n_cols)]
    _, ax = plt.subplots(1,1, figsize=(15,8))
    colors = sns.color_palette("Set2", len(files))
    for file, color in zip(files, colors):
        data = pd.DataFrame.from_csv(file)
        data['best_fitness'].plot(ax=ax, label=file, c=color)
    return ax

# %%
mutations = [(single_mutation, MatchSMStrategy)]
gems=[0, 5, 10]
n_cols=[10, 50, 100]

ax = plot_fitness(mutations, gems, n_cols)
ax.legend()
ax.set_xlim(0,1250)
ax.set_ylim(0.2, 1)
# Out:
# (0.2, 1)

# %%
mutations = [(point_mutation, MatchPMStrategy)]
gems = [0, 5, 10]
n_cols = [10, 50, 100]

ax = plot_fitness(mutations, gems, n_cols)
ax.legend()

# %%
mutations = [(probabilistic_mutation, MatchSMStrategy)]
gems = [0, 5, 10]
n_cols = [10, 50, 100]

ax = plot_fitness(mutations, gems, n_cols)
ax.legend()

# %%
mutations = [(probabilistic_mutation, MatchByActiveStrategy)]
gems = [0, 5, 10]
n_cols = [10, 50, 100]

ax = plot_fitness(mutations, gems, n_cols)
ax.legend()
