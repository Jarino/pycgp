# %%
import pickle
import os 
from itertools import product

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.style.use('seaborn')

from pycgp import single_mutation, point_mutation, probabilistic_mutation
from pycgp.gems import MatchByActiveStrategy, MatchPMStrategy, MatchSMStrategy

from utils import load_data, aggregate_statistics, plot_fitnesses, plot_distributions

# %% [markdown]
# This notebook interpret the results of basic run of symbolic regression - 30 applications of gems until it expires, replacement of the worst gem in jewellery box, 5 individuals in population.

# %% [markdown]
# # Aggregate statistics

# %%
mutations = [
        (single_mutation, MatchSMStrategy),
        (point_mutation, MatchPMStrategy),
        (probabilistic_mutation, MatchSMStrategy),
        (single_mutation, MatchByActiveStrategy),
        (probabilistic_mutation, MatchByActiveStrategy)]

folder = 'scripts/symbolic_out_pypy'
data = aggregate_statistics(folder, mutations)
data.head()
# Out:
#           mutation         strategy gems columns      best         mean  \
# 0  single_mutation  MatchSMStrategy    0      10  0.164081    18.946850
# 1  single_mutation  MatchSMStrategy    0      50  0.197690   136.767268
# 2  single_mutation  MatchSMStrategy    0     100  0.000000  8701.383057
# 3  single_mutation  MatchSMStrategy    5      10  0.000000     0.288831
# 4  single_mutation  MatchSMStrategy    5      50  0.054535  1213.767775
#
#             std  avg_gem_count  gem_better  gem_worse  \
# 0     39.092847            0.0        0.00        0.0
# 1    304.560115            0.0        0.00        0.0
# 2  19456.884013            0.0        0.00        0.0
# 3      0.393883            5.7       56.10       25.1
# 4   2713.902328            5.2       17.65        9.9
#
#                                                   bf  \
# 0  [1.2784660239823311, 0.6723966241088043, 0.629...
# 1  [1.1857974309090202, 0.6383268493123296, 0.610...
# 2  [0.8667326660578247, 0.7001217034283264, 0.648...
# 3  [1.1056050896944791, 0.7311589103347917, 0.642...
# 4  [0.8310599493886869, 0.6521411569934805, 0.622...
#
#                                                   mf
# 0  [175886293519055.5, 3.1613678389589843, 17743....
# 1  [1362.2602057189513, 495.7502595415788, 4.4248...
# 2  [4908596.728624338, 189143.49442647307, 468.81...
# 3  [206523.95718499264, 263.3072280355174, 27.849...
# 4  [2118300689.4841487, 187146289.4175294, 722.73...

# %%
data.groupby('gems').mean()
# Out:
#           best         mean          std  avg_gem_count  gem_better  \
# gems
# 0     0.080268  1250.526368  2787.777977       0.000000        0.00
# 5     0.022252    93.875414   208.820025       7.000000       44.24
# 10    0.038563   501.003898  1118.590968       9.956667       56.05
#
#        gem_worse
# gems
# 0       0.000000
# 5      92.486667
# 10    113.036667

# %% [markdown]
# Overall, gems brough significant improvement in terms of best fitness achieved and mean of generation containing best fitness. Intersting observation is the slightly worse result in case of 10 gems.
#
# Let's have a look at performance according to mutation and match strategy used.

# %%
data.groupby(['mutation', 'strategy']).mean()
# Out:
#                                                   best         mean  \
# mutation               strategy
# point_mutation         MatchPMStrategy        0.060857     2.585281
# probabilistic_mutation MatchByActiveStrategy  0.022458    69.240774
#                        MatchSMStrategy        0.013439    61.663120
# single_mutation        MatchByActiveStrategy  0.050635  1822.882180
#                        MatchSMStrategy        0.087748  1119.304780
#
#                                                       std  avg_gem_count  \
# mutation               strategy
# point_mutation         MatchPMStrategy           5.529199       5.350000
# probabilistic_mutation MatchByActiveStrategy   146.823561       5.677778
#                        MatchSMStrategy         129.219100       4.522222
# single_mutation        MatchByActiveStrategy  4074.997742       7.861111
#                        MatchSMStrategy        2502.078682       4.850000
#
#                                               gem_better   gem_worse
# mutation               strategy
# point_mutation         MatchPMStrategy         83.427778   22.894444
# probabilistic_mutation MatchByActiveStrategy   21.933333  123.122222
#                        MatchSMStrategy          0.550000    0.905556
# single_mutation        MatchByActiveStrategy   37.938889  180.616667
#                        MatchSMStrategy         23.300000   15.000000

# %%
data[bitfilter]
# Out:
#                   mutation               strategy gems columns      best  \
# 36  probabilistic_mutation  MatchByActiveStrategy    0      10  0.120955
# 37  probabilistic_mutation  MatchByActiveStrategy    0      50  0.000000
# 38  probabilistic_mutation  MatchByActiveStrategy    0     100  0.000000
# 39  probabilistic_mutation  MatchByActiveStrategy    5      10  0.000000
# 40  probabilistic_mutation  MatchByActiveStrategy    5      50  0.000000
# 41  probabilistic_mutation  MatchByActiveStrategy    5     100  0.081169
# 42  probabilistic_mutation  MatchByActiveStrategy   10      10  0.000000
# 43  probabilistic_mutation  MatchByActiveStrategy   10      50  0.000000
# 44  probabilistic_mutation  MatchByActiveStrategy   10     100  0.000000
#
#           mean          std  avg_gem_count  gem_better  gem_worse  \
# 36  502.663052  1073.819033           0.00        0.00       0.00
# 37    6.679342     7.928396           0.00        0.00       0.00
# 38    1.543190     1.894250           0.00        0.00       0.00
# 39   25.403744    55.903581           8.45       44.65     193.70
# 40    1.338989     2.029421           7.90       26.95     173.90
# 41    1.852581     3.173201           7.70       24.70     162.70
# 42   14.086813    25.271333           7.65       38.40     173.05
# 43   43.976051    95.581366          10.25       35.05     220.25
# 44   25.623205    55.811469           9.15       27.65     184.50
#
#                                                    bf  \
# 36  [1.0209055948453207, 0.7826463917384264, 0.633...
# 37  [0.7477143630082558, 0.6668741096211008, 0.623...
# 38  [0.8839623337943168, 0.626050266144915, 0.6031...
# 39  [0.7762824714805141, 0.7515542771306852, 0.666...
# 40  [0.7382410664734386, 0.6471362437047095, 0.631...
# 41  [0.755016953343006, 0.6579223172247023, 0.6419...
# 42  [0.7318191191480266, 0.6990065568008532, 0.614...
# 43  [0.8556067299804255, 0.7287175022980149, 0.645...
# 44  [0.7680086409932757, 0.6756148751506033, 0.644...
#
#                                                    mf
# 36  [376816.6148763037, 609.8263727320807, 53.2357...
# 37  [19822.590532008955, 9628.555652221727, 12348....
# 38  [1550747240048.5671, 35904.69839749506, 19.661...
# 39  [1769.6990019403795, 4289.284745928035, 133.06...
# 40  [9063464794559.713, 854.91081053703, 101436284...
# 41  [10214.911852685324, 482826.06048998487, 42333...
# 42  [62.57199621109421, 83.62627747393557, 133.828...
# 43  [780551.5837308174, 161.92933100175742, 216.39...
# 44  [237759453.65975055, 12458.245561174228, 7.303...

# %% [markdown]
# Best performance was achieved by probabilistic mutation, using match by all strategy. Let's have a look at its performance according to JBox size.

# %%
data[(data['mutation'] == 'probabilistic_mutation') & (data['strategy'] == 'MatchSMStrategy' )].iloc[:,:-2]
# Out:
#                   mutation         strategy gems columns      best  \
# 18  probabilistic_mutation  MatchSMStrategy    0      10  0.120955
# 19  probabilistic_mutation  MatchSMStrategy    0      50  0.000000
# 20  probabilistic_mutation  MatchSMStrategy    0     100  0.000000
# 21  probabilistic_mutation  MatchSMStrategy    5      10  0.000000
# 22  probabilistic_mutation  MatchSMStrategy    5      50  0.000000
# 23  probabilistic_mutation  MatchSMStrategy    5     100  0.000000
# 24  probabilistic_mutation  MatchSMStrategy   10      10  0.000000
# 25  probabilistic_mutation  MatchSMStrategy   10      50  0.000000
# 26  probabilistic_mutation  MatchSMStrategy   10     100  0.000000
#
#           mean          std  avg_gem_count  gem_better  gem_worse
# 18  502.663052  1073.819033           0.00        0.00       0.00
# 19    6.679342     7.928396           0.00        0.00       0.00
# 20    1.543190     1.894250           0.00        0.00       0.00
# 21   26.880537    58.800892           5.00        1.20       2.15
# 22    6.679342     7.928396           5.00        0.00       0.00
# 23    1.543190     1.894250           4.90        0.00       0.00
# 24    0.756892     0.884032           8.10        3.75       6.00
# 25    6.679342     7.928396           9.15        0.00       0.00
# 26    1.543190     1.894250           8.55        0.00       0.00

# %% [markdown]
# An interesting observation here: on larger graphs, no gems were actually used. This could by due to very low probability of match by all strategy on larger graph. Only on small graphs (size 10) the gems were applied. Positive fact is, that even small number of gems applications on those small graphs leads to better results.
#
# What about peformance of gems with match by active strategy?
#
# Will we observe similar behaviour on Match By All strategy with single mutation?

# %%
data[(data['mutation'] == 'probabilistic_mutation') & (data['strategy'] == 'MatchByActiveStrategy' )].iloc[:,:-2]
# Out:
#                   mutation               strategy gems columns      best  \
# 36  probabilistic_mutation  MatchByActiveStrategy    0      10  0.120955
# 37  probabilistic_mutation  MatchByActiveStrategy    0      50  0.000000
# 38  probabilistic_mutation  MatchByActiveStrategy    0     100  0.000000
# 39  probabilistic_mutation  MatchByActiveStrategy    5      10  0.000000
# 40  probabilistic_mutation  MatchByActiveStrategy    5      50  0.000000
# 41  probabilistic_mutation  MatchByActiveStrategy    5     100  0.081169
# 42  probabilistic_mutation  MatchByActiveStrategy   10      10  0.000000
# 43  probabilistic_mutation  MatchByActiveStrategy   10      50  0.000000
# 44  probabilistic_mutation  MatchByActiveStrategy   10     100  0.000000
#
#           mean          std  avg_gem_count  gem_better  gem_worse
# 36  502.663052  1073.819033           0.00        0.00       0.00
# 37    6.679342     7.928396           0.00        0.00       0.00
# 38    1.543190     1.894250           0.00        0.00       0.00
# 39   25.403744    55.903581           8.45       44.65     193.70
# 40    1.338989     2.029421           7.90       26.95     173.90
# 41    1.852581     3.173201           7.70       24.70     162.70
# 42   14.086813    25.271333           7.65       38.40     173.05
# 43   43.976051    95.581366          10.25       35.05     220.25
# 44   25.623205    55.811469           9.15       27.65     184.50

# %%
data[(data['mutation'] == 'single_mutation') & (data['strategy'] == 'MatchSMStrategy' )].iloc[:,:-2]
# Out:
#           mutation         strategy gems columns      best         mean  \
# 0  single_mutation  MatchSMStrategy    0      10  0.164081    18.946850
# 1  single_mutation  MatchSMStrategy    0      50  0.197690   136.767268
# 2  single_mutation  MatchSMStrategy    0     100  0.000000  8701.383057
# 3  single_mutation  MatchSMStrategy    5      10  0.000000     0.288831
# 4  single_mutation  MatchSMStrategy    5      50  0.054535  1213.767775
# 5  single_mutation  MatchSMStrategy    5     100  0.000000     0.826399
# 6  single_mutation  MatchSMStrategy   10      10  0.174195     1.163281
# 7  single_mutation  MatchSMStrategy   10      50  0.103543     0.187046
# 8  single_mutation  MatchSMStrategy   10     100  0.095693     0.412510
#
#             std  avg_gem_count  gem_better  gem_worse
# 0     39.092847           0.00        0.00       0.00
# 1    304.560115           0.00        0.00       0.00
# 2  19456.884013           0.00        0.00       0.00
# 3      0.393883           5.70       56.10      25.10
# 4   2713.902328           5.20       17.65       9.90
# 5      1.334114           5.10       10.85      11.95
# 6      1.962070           7.85       74.65      39.15
# 7      0.183254           9.80       27.50      22.25
# 8      0.395515          10.00       22.95      26.65

# %% [markdown]
# Here, when it comes to 5 gems,the results are slightly better, in 10 gems case, the results are however slightly worse.
#
# So we see, that best performance can be achieved by probabilistic mutation and match by all strategy and gems can further improve this performance, albeit slightly. Let's see which mutation performed worst and see effect of gems on this settings.

# %%
data[data.gems == 0].groupby('mutation').mean()
# Out:
#                             best         mean          std  avg_gem_count  \
# mutation
# point_mutation          0.079523     7.310003    16.104115            0.0
# probabilistic_mutation  0.040318   170.295195   361.213893            0.0
# single_mutation         0.120590  2952.365725  6600.178992            0.0
#
#                         gem_better  gem_worse
# mutation
# point_mutation                 0.0        0.0
# probabilistic_mutation         0.0        0.0
# single_mutation                0.0        0.0

# %% [markdown]
# As with *remove oldest* gem removal, worse performance was provided by single mutation. Let's have a closer look at that.

# %%
data[(data['mutation'] == 'single_mutation')].groupby(['strategy', 'gems']).mean()
# Out:
#                                 best         mean          std  avg_gem_count  \
# strategy              gems
# MatchByActiveStrategy 0     0.120590  2952.365725  6600.178992       0.000000
#                       5     0.016157    42.977496    95.444934      10.250000
#                       10    0.015157  2473.303318  5529.369300      13.333333
# MatchSMStrategy       0     0.120590  2952.365725  6600.178992       0.000000
#                       5     0.018178   404.961001   905.210108       5.333333
#                       10    0.124477     0.587612     0.846947       9.216667
#
#                             gem_better   gem_worse
# strategy              gems
# MatchByActiveStrategy 0       0.000000    0.000000
#                       5      50.716667  240.833333
#                       10     63.100000  301.016667
# MatchSMStrategy       0       0.000000    0.000000
#                       5      28.200000   15.650000
#                       10     41.700000   29.350000

# %% [markdown]
# Interesting property is the worse performance of match by all strategy, when using 10 JBox size. We do not see this in case of *oldest removal*. Other than that, runs with gems yielded better results on average.
#
# Let's plot the average best fitness of probabilistic and single mutations.

# %%
plot_fitnesses(data, 'probabilistic_mutation', (0.15, 0.6))

# %%
plot_fitnesses(data, 'single_mutation', (0.15, 0.6))

# %%
plot_fitnesses(data, 'single_mutation', (0.15, 0.6))

# %%
plot_fitnesses(data, 'point_mutation', (0.15, 0.6))

# %%
ax = plot_distributions(folder, mutations)
ax.set_xlabel('Mean squared error')
plt.savefig('test.pdf', format='pdf', dpi=1000)

# %% [markdown]
# # Conclusion
#
# Gems were able to improve performance in almost all instances of experiment. Best performance overall was achieved by
